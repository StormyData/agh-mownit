# %% [markdown]
# # Zestaw 5
#
# ## Tobiasz Szulc
#
#
#
# ### Zadanie 1

# %%
import zadanie1
zadanie1.draw()
zadanie1.draw()
zadanie1.draw()
zadanie1.draw2()

# %% [markdown]
# ### Zadanie 2

# %%
import zadanie2
zadanie2.draw(500)
zadanie2.draw(100)
zadanie2.draw(10)
zadanie2.draw(1)
zadanie2.draw_plot()
# Out:
# 507
